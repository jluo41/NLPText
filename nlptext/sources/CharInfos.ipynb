# %%
import pickle


with open('CharRadical.p', 'rb') as handle:
    charRadicalDict = pickle.load(handle)

# %%
charRadicalDict['病']
# Out:
# '疒'

# %%
len(data)
# Out:
# 386

# %%
data = [i for i in charRadicalDict if charRadicalDict[i] in ['疒', '月', '骨']]

idx = 380


a = ['骼', '胖',  '膂',  '癣',  '疤', '胃', 
'癌', '瘢', '臃','疠', '髓',  '胚', 
'癔', '瘪', '胱', '脛', '膝', '脲', '髋', '肝',
'膊', '骸', '痒', '瘦', '股',  '腠', '疘', '瘃', '骰','疫', '痂',
'肥', '腑', '脐', '疳', '腻',
'痊', '痴', '脾', '肩', '癲',
'痰', '髃', '腕', '腿', '胀', '疣', '瘥',
'臀', '瘸', '肭', '痤', '脘', 
'肚', '脯', '朊', '腆', '胛', '疾', '髌',
'肱', '腰', '痨',   '痿',  '瘩', 
'脉', '胈', '臈', '臟', '腴',  '肋',
'疮',  '痘', '胶', '病',  '癃', '背',  '瘙',
'肢', '痫',  '癭', '髈', '腥',
'膏', '疗', '癖',  '瘴', '痉', '脑', '膦', 
'髀', '疟', '癞', '腼', '肓', '腩',
'疲', '肪',  '瘤', '疹', '胫',
'痣', '膀', '脂', '腭', '腚', '胯','肛','腱', '膛','育', '骶', '痔', '胳','脊','疽',
'腋', '瘘', '肌', '疚',   '疖', '腹', '脸','瘫', '肺',
'痛', '肾', '脖','痹','臂','疡','肘','膘', '癍', '脚','骨', '痢', '臆', '胰', '胆', '瘾','膜',
'疼','肠','胸', '胎','腺', '肤', '癫', '脏', '膑', '瘟', '疴','癜',
'痱', '脓','膨', '疝', '肿','症', '腔']
data[idx:idx+10]
# Out:
# ['瘛', '皰', '朐', '膿', '症', '腔']

# %%
''.join(a)
# Out:
# '骼胖膂癣疤胃癌瘢臃疠髓胚癔瘪胱脛膝脲髋肝膊骸痒瘦股腠疘瘃骰疫痂肥腑脐疳腻痊痴脾肩癲痰髃腕腿胀疣瘥臀瘸肭痤脘肚脯朊腆胛疾髌肱腰痨痿瘩脉胈臈臟腴肋疮痘胶病癃背瘙肢痫癭髈腥膏疗癖瘴痉脑膦髀疟癞腼肓腩疲肪瘤疹胫痣膀脂腭腚胯肛腱膛育骶痔胳脊疽腋瘘肌疚疖腹脸瘫肺痛肾脖痹臂疡肘膘癍脚骨痢臆胰胆瘾膜疼肠胸胎腺肤癫脏膑瘟疴癜痱脓膨疝肿症腔'

# %%
import pickle


with open('CharInfos.p', 'rb') as handle:
    charInfosDict = pickle.load(handle)

# %%
charInfosDict
# Out:
# {'卥': {'SubComps': ['38', '120', '129'],
#   'Strokes': ['2', '1', '2', '5', '3', '3', '4', '1']},
#  '串': {'SubComps': ['431'], 'Strokes': ['2', '5', '1', '2', '5', '1', '2']},
#  '卡': {'SubComps': ['38', '1', '37'], 'Strokes': ['2', '1', '1', '2', '4']},
#  '临': {'SubComps': ['3', '3', '42', '6', '215'],
#   'Strokes': ['2', '2', '3', '1', '4', '2', '5', '2', '1']},
#  '丳': {'SubComps': ['119', '119', '4', '3'],
#   'Strokes': ['2', '5', '1', '2', '5', '1', '3', '2']},
#  '丰': {'SubComps': ['227'], 'Strokes': ['1', '1', '1', '2']},
#  '巻': {'SubComps': ['70', '176', '143'],
#   'Strokes': ['4', '3', '1', '1', '3', '4', '5', '1', '5']},
#  '丱': {'SubComps': ['351'], 'Strokes': ['5', '3', '2', '1', '2']},
#  '彝': {'SubComps': ['164', '405', '169', '160', '108'],
#   'Strokes': ['5',
#    '5',
#    '1',
#    '4',
#    '3',
#    '1',
#    '2',
#    '3',
#    '4',
#    '5',
#    '5',
#    '4',
#    '2',
#    '3',
#    '4',
#    '1',
#    '1',
#    '2']},
# ...

# %%
charSubCompDict = {}

for i in charInfosDict:
    charSubCompDict[i] = charInfosDict[i]['SubComps']

# %%
len(charSubCompDict)
# Out:
# 20864

# %%
charStrokeDict = {}

for i in charInfosDict:
    charStrokeDict[i] = charInfosDict[i]['Strokes']

# %%
charStrokeDict
# Out:
# {'卥': ['2', '1', '2', '5', '3', '3', '4', '1'],
#  '串': ['2', '5', '1', '2', '5', '1', '2'],
#  '卡': ['2', '1', '1', '2', '4'],
#  '临': ['2', '2', '3', '1', '4', '2', '5', '2', '1'],
#  '丳': ['2', '5', '1', '2', '5', '1', '3', '2'],
#  '丰': ['1', '1', '1', '2'],
#  '巻': ['4', '3', '1', '1', '3', '4', '5', '1', '5'],
#  '丱': ['5', '3', '2', '1', '2'],
#  '彝': ['5',
#   '5',
#   '1',
#   '4',
#   '3',
#   '1',
#   '2',
#   '3',
#   '4',
#   '5',
#   '5',
#   '4',
#   '2',
#   '3',
#   '4',
#   '1',
#   '1',
#   '2'],
#  '彜': ['5',
#   '5',
#   '1',
#   '4',
#   '3',
#   '1',
#   '2',
#   '3',
#   '4',
#   '3',
#   '4',
#   '5',
#   '3',
#   '1',
#   '3',
#   '2'],
#  '彙': ['5', '5', '1', '4', '5', '2', '5', '1', '1', '1', '2', '3', '4'],
#  '彘': ['5', '5', '1', '3', '1', '1', '3', '4', '1', '5', '3', '5'],
#  '彖': ['5', '5', '1', '3', '5', '3', '3', '3', '4'],
#  '彔': ['5', '5', '1', '2', '4', '1', '3', '4'],
#  '彑': ['5', '5', '1'],
#  '广': ['4', '1', '3'],
# ...

# %%
import pickle 

with open('CharSubComp.p', 'wb') as handle:
    pickle.dump(charSubCompDict,handle)

# %%
import pickle 

with open('CharStroke.p', 'wb') as handle:
    pickle.dump(charStrokeDict,handle)
